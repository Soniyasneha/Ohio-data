# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={'cause of deaths':['Chronic Disease',' Unintetional Injuries', 'Alzheimers', 'Infuenza and Pneumonia', 'Sepsis','Others'],'Percentile':[62, 5, 4, 2, 1 , 26]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#           cause of deaths  Percentile
# 0         Chronic Disease          62
# 1   Unintetional Injuries           5
# 2              Alzheimers           4
# 3  Infuenza and Pneumonia           2
# 4                  Sepsis           1
# 5                  Others          26

# %%
df.plot.pie(y='Percentile',labels=df['cause of deaths'],figsize=(10,18))
